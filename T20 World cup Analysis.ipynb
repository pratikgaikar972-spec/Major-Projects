# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
world_cup=pd.read_csv("ICC Mens T20 Worldcup.csv")
world_cup.head()
# Out:
#   Match No.                  Date  \
# 0       1st  Saturday,June 1,2024
# 1       2nd    Sunday,June 2,2024
# 2       3rd    Sunday,June 2,2024
# 3       4th    Monday,June 3,2024
# 4       5th    Monday,June 3,2024
#
#                                                Venue          1st Team  \
# 0                      Grand Prairie Stadium, Dallas            Canada
# 1                         Providence Stadium, Guyana  Papua New Guinea
# 2              Kensington Oval, Bridgetown, Barbados              Oman
# 3  Nassau County International Cricket Stadium, N...         Sri Lanka
# 4                         Providence Stadium, Guyana       Afghanistan
#
#                   2nd Team    Stage             Toss Winning Toss Decision  \
# 0  United State Of America  Group A  United State Of America      Fielding
# 1              Afghanistan  Group C              Afghanistan      Fielding
# 2                  Namibia  Group B                  Namibia      Fielding
# ...

# %%
print(world_cup.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Match No.                          55 non-null     object
#  1   Date                               55 non-null     object
#  2   Venue                              55 non-null     object
#  3   1st Team                           55 non-null     object
#  4   2nd Team                           55 non-null     object
#  5   Stage                              55 non-null     object
#  6   Toss Winning                       55 non-null     object
#  7   Toss Decision                      55 non-null     object
#  8   First Innings Score                55 non-null     object
#  9   Fall of wickets First Innings      55 non-null     object
#  10  Second Innings Score               55 non-null     object
# ...

# %%
print(world_cup.isnull().sum())# checking null values
# Out:
# Match No.                            0
# Date                                 0
# Venue                                0
# 1st Team                             0
# 2nd Team                             0
# Stage                                0
# Toss Winning                         0
# Toss Decision                        0
# First Innings Score                  0
# Fall of wickets First Innings        0
# Second Innings Score                 0
# Fall of wickets Second Innings       0
# Winners                              0
# Method                               0
# Won by                               0
# Winning Margin                       0
# Top Scorer                           0
# Highest Score                        0
# Best Bowler                          0
# Best Bowler Figure(Wickets Taken)    0
# Best Bowler Figure(Runs Recieved)    0
# Player Of The Match                  0
# dtype: int64

# %%
print(world_cup["1st Team"].unique())#exploring all the teams 
print(world_cup["2nd Team"].unique())
# Out:
# ['Canada' 'Papua New Guinea' 'Oman' 'Sri Lanka' 'Afghanistan' 'Scotland'
#  'Nepal' 'Ireland' 'Australia' 'Pakistan' 'Namibia' 'Netherlands'
#  'West Indies' 'India' 'South Africa' 'United State Of America'
#  'Bangladesh' 'Uganda' 'England']
# ['United State Of America' 'Afghanistan' 'Namibia' 'South Africa' 'Uganda'
#  'England' 'Netherlands' 'India' 'Oman' 'Scotland' 'Ireland' 'New Zealand'
#  'Bangladesh' 'Pakistan' 'Sri Lanka' 'Australia' 'Nepal' 'West Indies']

# %%
print(world_cup[world_cup["Stage"]=="Final"]["Winners"])#winner of the World Cup
# Out:
# 54    India
# Name: Winners, dtype: object

# %%
# Teams with the highest count are the most consistent match winners and are top performers in the tournament
print(world_cup["Winners"].value_counts())
# Out:
# Winners
# South Africa               8
# India                      8
# Afghanistan                6
# Australia                  5
# Rain                       4
# England                    4
# West Indies                4
# Bangladesh                 3
# New Zealand                2
# Pakistan                   2
# United State Of America    2
# Scotland                   2
# Canada                     1
# Uganda                     1
# Netherlands                1
# Namibia                    1
# Sri Lanka                  1
# Name: count, dtype: int64

# %%
winners = world_cup["Winners"].value_counts().reset_index(name="wins")
plt.figure(figsize=(6,3))
sns.barplot(winners,x="Winners",y="wins",color="#00B7B5",edgecolor="k")
plt.title("Most Successful Teams in T20 World Cup",fontdict={"color":"#11224E","fontfamily":"monospace"})
plt.xlabel("Teams",fontdict={"color":"#11224E","fontfamily":"monospace"})
plt.ylabel("Matches Won",fontdict={"color":"#11224E","fontfamily":"monospace"})
plt.xticks(rotation=90)
plt.show()

# %%
toss_win = world_cup["Toss Winning"].value_counts().reset_index(name="wins")
plt.figure(figsize=(6,3))
sns.barplot(toss_win,x="Toss Winning",y="wins",color="#CD2C58",edgecolor="k")
plt.title("Toss Winners Count",fontdict={"color":"#11224E","fontfamily":"monospace"})
plt.ylabel("Frequency",fontdict={"color":"#11224E","fontfamily":"monospace"})
plt.xticks(rotation=90)
plt.show()

# %%
venue = world_cup["Venue"].value_counts().reset_index(name="counts").head(10)
plt.figure(figsize=(5,3))
sns.barplot(venue,x="counts",y="Venue",orient="h",color="#3B9797",edgecolor="k")
plt.title("Top 10 Most Used Venues",fontdict={"color":"#11224E","fontfamily":"monospace"})
plt.xlabel("counts",fontdict={"color":"#11224E","fontfamily":"monospace"})
plt.ylabel("Venue",fontdict={"color":"#11224E","fontfamily":"monospace"})
plt.show()

# %%
win_type=world_cup["Won by"].value_counts()
plt.pie(win_type,labels=["Runs","Wickets","Rain"],colors=["#73C8D2","#FFA4A4","#F5F1DC"],shadow=True,wedgeprops={"edgecolor":"k","linewidth":1.3})
plt.title("Match Win Type Distribution",fontdict={"color":"#11224E","fontfamily":"monospace"})
plt.show()

# %%
win_per=world_cup.groupby("Winners").size().reset_index(name="wins")
winners = win_per["wins"].sum()
win_per["win_percentage"]=(win_per["wins"]/winners)*100
win_per=win_per.sort_values(by="win_percentage",ascending=False)
sns.barplot(win_per,x="Winners",y="win_percentage",hue="wins",palette="muted")
plt.xticks(rotation=90)
plt.show()

# %%
# Batsman with highest Score 
Top_scorer=world_cup[["Highest Score","Top Scorer"]].sort_values(by="Highest Score",ascending=False).head(15)
Top_scorer.drop([5,32,29,22],inplace=True)
sns.relplot(Top_scorer,x="Top Scorer",y="Highest Score",hue='Top Scorer',marker="p")
plt.xticks(rotation=90)
plt.show()
